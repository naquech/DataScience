# %%
import pandas as pd
import numpy as np

# %%
column = pd.read_csv('Data/spl_18.csv')
column.head()
# Out:
# /Users/natalia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning:
#
# Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth Checkouts  \
# 0    Digital      Freegal         SONG          2018              1         1
# 1    Digital      Freegal         SONG          2018              1         1
# 2    Digital      Freegal         SONG          2018              1         1
# 3    Digital      Freegal         SONG          2018              1         1
# 4    Digital    OverDrive    AUDIOBOOK          2018              1         1
#
#                       Title                   Creator             Subjects  \
# 0         Exploding Chimney                  The Fall                  NaN
# 1  Swing Low, Sweet Chariot            Alex de Grassi                  NaN
# 2             Fear Not Mary  Will Ackerman;Nick Berry                  NaN
# ...

# %%
import plotly.plotly as py
import seaborn as sns

# %%
series = column['MaterialType'].value_counts();
series.plot(kind='bar', figsize=(25, 10), title='Material Type Counts')

# %%
sns.catplot(x="MaterialType", kind="count", data=column, aspect=5);

# %%
#year_2017 = column[column.CheckoutYear == 2017].head()
subjects_2017= column.sort_values('Subjects', ascending=False)
subjects_2017.head()
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 870922    Physical      Horizon         BOOK          2018              4
# 2041484   Physical      Horizon         BOOK          2018             10
# 1177303   Physical      Horizon         BOOK          2018              6
# 442162    Physical      Horizon         BOOK          2018              2
# 2293550   Physical      Horizon         BOOK          2018             11
#
#         Checkouts                                              Title  \
# 870922          1  Forty days : the diary of a traditional solita...
# 2041484         1  Ein Garten Eden : Meisterwerke der botanischen...
# 1177303         1  Ein Garten Eden : Meisterwerke der botanischen...
# 442162          1  Ein Garten Eden : Meisterwerke der botanischen...
# 2293550         5  Omer Pasha Latas / Ivo Andrić ; translated fro...
#
#                          Creator  \
# 870922      Özelsel, Michaela M.
# 2041484          Lack, H. Walter
# ...

# %%
column.Checkouts.dtype
# Out:
# dtype('O')

# %%
column.Checkouts.unique()
# Out:
# array([1, 2, 14, 4, 5, 3, 6, 7, 11, 10, 34, 19, 9, 35, 16, 64, 21, 8, 13,
#        12, 30, 17, 20, 22, 18, 15, 79, 50, 61, 32, 95, 23, 24, 71, 38, 29,
#        43, 44, 25, 39, 28, 26, 65, 105, 56, 42, 58, 84, 51, 106, 81, 27,
#        82, 62, 66, 46, 57, 41, 114, 59, 86, 85, 540, 89, 80, 78, 76, 60,
#        55, 54, 176, 47, 31, 40, 354, 48, 495, 37, 282, 119, 141, 251, 102,
#        143, 49, 63, 87, 33, 179, 70, 99, 52, 92, 53, 68, 45, 72, 122, 123,
#        667, 117, 97, 96, 121, 183, 241, 36, 157, 277, 130, 568, 110, 90,
#        77, 100, 601, 158, 200, 136, 187, 479, 399, 75, 67, 284, 170, 132,
#        164, 73, 551, 142, 69, 155, 185, 103, 156, 138, 627, 83, 267, 93,
#        586, 109, 654, 124, 107, 543, 134, 108, 88, 101, 74, 205, 112, 91,
#        139, 167, 188, 149, 145, '1', '2', '3', '6', '5', '4', '7', '12',
#        '18', '13', '16', '92', '56', '30', '196', '9', '14', '46', '8',
#        '15', '27', '17', '10', '28', '65', '26', '37', '24', '11', '32',
# ...

# %%
column['Checkouts'] = column['Checkouts'].str.replace(',', '')

# %%
column.Checkouts.unique()
# Out:
# array([nan, '1', '2', '3', '6', '5', '4', '7', '12', '18', '13', '16',
#        '92', '56', '30', '196', '9', '14', '46', '8', '15', '27', '17',
#        '10', '28', '65', '26', '37', '24', '11', '32', '21', '57', '40',
#        '75', '69', '33', '19', '76', '22', '39', '31', '72', '29', '45',
#        '20', '34', '51', '38', '47', '25', '35', '88', '67', '50', '54',
#        '114', '49', '96', '70', '59', '41', '118', '84', '93', '43', '44',
#        '71', '87', '36', '334', '23', '77', '73', '61', '83', '64', '52',
#        '48', '111', '420', '103', '94', '42', '81', '90', '58', '79',
#        '82', '125', '165', '95', '91', '284', '143', '74', '55', '86',
#        '53', '63', '261', '212', '62', '132', '549', '131', '211', '89',
#        '102', '147', '68', '432', '202', '107', '98', '148', '494', '99',
#        '552', '100', '97', '1175', '164', '309', '170', '134', '206',
#        '277', '331', '194', '142', '120', '228', '220', '198', '60',
# ...

# %%
column['Checkouts'].isna().sum()
# Out:
# 1878666

# %%
column.loc[column['Checkouts'] == '1148']
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 2458304    Digital        Zinio     MAGAZINE          2018             12
#
#         Checkouts           Title Creator Subjects Publisher PublicationYear
# 2458304      1148  The New Yorker     NaN      NaN       NaN             NaN

# %%
column.UsageClass.isna().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt

# %%
data['Checkouts'] = pd.to_numeric(data['Checkouts'], errors='coerce')

# %%
physical = column[column.UsageClass == 'Physical']
digital = column[column.UsageClass == 'Digital']

# %%
column.groupby(['CheckoutMonth','UsageClass']).size().unstack().plot(kind='line',stacked=True);

# %%
data1.shape
# Out:
# (2665098, 11)

# %%
data1 = pd.read_csv('Data/spl_18.csv', thousands=',');

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665098 entries, 0 to 2665097
# Data columns (total 11 columns):
# UsageClass         object
# CheckoutType       object
# MaterialType       object
# CheckoutYear       int64
# CheckoutMonth      int64
# Checkouts          int64
# Title              object
# Creator            object
# Subjects           object
# Publisher          object
# PublicationYear    object
# dtypes: int64(3), object(8)
# memory usage: 223.7+ MB

# %%
data1.Checkouts.unique()
# Out:
# array([   1,    2,   14,    4,    5,    3,    6,    7,   11,   10,   34,
#          19,    9,   35,   16,   64,   21,    8,   13,   12,   30,   17,
#          20,   22,   18,   15,   79,   50,   61,   32,   95,   23,   24,
#          71,   38,   29,   43,   44,   25,   39,   28,   26,   65,  105,
#          56,   42,   58,   84,   51,  106,   81,   27,   82,   62,   66,
#          46,   57,   41,  114,   59,   86,   85,  540,   89,   80,   78,
#          76,   60,   55,   54,  176,   47,   31,   40,  354,   48,  495,
#          37,  282,  119,  141,  251,  102,  143,   49,   63,   87,   33,
#         179,   70,   99,   52,   92,   53,   68,   45,   72,  122,  123,
#         667,  117,   97,   96,  121,  183,  241,   36,  157,  277,  130,
#         568,  110,   90,   77,  100,  601,  158,  200,  136,  187,  479,
#         399,   75,   67,  284,  170,  132,  164,   73,  551,  142,   69,
#         155,  185,  103,  156,  138,  627,   83,  267,   93,  586,  109,
# ...

# %%
data1.Checkouts.isna().sum()
# Out:
# 0

# %%
data1.Checkouts.dtype
# Out:
# dtype('int64')

# %%
data1.loc[data1['Checkouts'] > 900]
# Out:
#         UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 101444    Physical      Horizon        MIXED          2018              1
# 450315    Physical      Horizon        MIXED          2018              2
# 491864    Physical      Horizon        MIXED          2018              3
# 808052    Physical      Horizon        MIXED          2018              4
# 1002722   Physical      Horizon        MIXED          2018              5
# 1275450   Physical      Horizon        MIXED          2018              6
# 1495009   Physical      Horizon        MIXED          2018              7
# 1650920   Physical      Horizon        MIXED          2018              8
# 1991369   Physical      Horizon        MIXED          2018              9
# 2070378   Physical      Horizon        MIXED          2018             10
# 2326874    Digital        Zinio     MAGAZINE          2018             11
# 2458304    Digital        Zinio     MAGAZINE          2018             12
#
# ...

# %%
#### Drop items checked out in 2019

data.info()
data.drop(data[data.CheckoutYear == 2019].index, inplace=True)
data['CheckoutYear'].value_counts()

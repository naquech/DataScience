# %%
import pandas as pd
import numpy as np

# %%
column = pd.read_csv('Data/spl_18.csv')
column.head()
# Out:
# /Users/natalia/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth Checkouts  \
# 0    Digital      Freegal         SONG          2018              1         1
# 1    Digital      Freegal         SONG          2018              1         1
# 2    Digital      Freegal         SONG          2018              1         1
# 3    Digital      Freegal         SONG          2018              1         1
# 4    Digital    OverDrive    AUDIOBOOK          2018              1         1
#
#                       Title                   Creator             Subjects  \
# 0         Exploding Chimney                  The Fall                  NaN
# 1  Swing Low, Sweet Chariot            Alex de Grassi                  NaN
# ...

# %%
column.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2665098 entries, 0 to 2665097
# Data columns (total 11 columns):
# UsageClass         int64
# CheckoutType       object
# MaterialType       object
# CheckoutYear       int64
# CheckoutMonth      int64
# Checkouts          object
# Title              object
# Creator            object
# Subjects           object
# Publisher          object
# PublicationYear    object
# dtypes: int64(3), object(8)
# memory usage: 223.7+ MB

# %%
data = column.copy(deep=True)
data.head()
# Out:
#    UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0           0      Freegal         SONG          2018              1
# 1           0      Freegal         SONG          2018              1
# 2           0      Freegal         SONG          2018              1
# 3           0      Freegal         SONG          2018              1
# 4           0    OverDrive    AUDIOBOOK          2018              1
#
#   Checkouts                     Title                   Creator  \
# 0         1         Exploding Chimney                  The Fall
# 1         1  Swing Low, Sweet Chariot            Alex de Grassi
# 2         1             Fear Not Mary  Will Ackerman;Nick Berry
# 3         1          Honky Tonk Flame            Tyler Childers
# 4         1  The Suitors (Unabridged)        Cecile David-Weill
#
#               Subjects               Publisher PublicationYear
# 0                  NaN                     NaN             NaN
# ...

# %%
data2 = pd.get_dummies(data2)
